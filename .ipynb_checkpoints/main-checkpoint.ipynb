# %% [markdown]
# # Load & Preview Data

# %%
import pandas as pd
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt

df = pd.read_csv("trends1.csv", sep=",")
#Rearrange the columns date first 
df = df[['date','top 1','top 2','top 3']]
df["date"] = pd.to_datetime(df["date"])
df.head()
# Out:
#         date  top 1  top 2  top 3
# 0 2012-10-07      4     14     14
# 1 2012-10-14      7     15     18
# 2 2012-10-21      5     12     15
# 3 2012-10-28      5     15     12
# 4 2012-11-04      4     12     12

# %%
df["date"].head()
# Out:
# 0   2012-10-07
# 1   2012-10-14
# 2   2012-10-21
# 3   2012-10-28
# 4   2012-11-04
# Name: date, dtype: datetime64[ns]

# %%
df["top 1"].head().values
# Out:
# array([4, 7, 5, 5, 4], dtype=int64)

# %%
df_plot = pd.DataFrame({
   'T1': df["top 1"].values,
   'T2': df["top 2"].values,
   'T3': df["top 3"].values
   }, index=pd.to_datetime(df["date"])
                    )
print("Preview")
print(df_plot.tail())
# Out:
# Preview
#             T1  T2  T3
# date
# 2017-09-03  18  72  35
# 2017-09-10  17  67  37
# 2017-09-17  18  66  32
# 2017-09-24  19  62  31
# 2017-10-01  20  78  27

# %%
#LAST 12 MONTH Data 
last12M = df_plot.last('12M')

lines = last12M.plot.line()

# %%
last12M.describe()
# Out:
#               T1          T2         T3
# count  48.000000   48.000000  48.000000
# mean   20.229167   72.520833  32.166667
# std     2.494586   16.514326   5.922670
# min    16.000000   45.000000  20.000000
# 25%    19.000000   57.750000  27.000000
# 50%    20.000000   72.500000  32.000000
# 75%    21.000000   87.250000  37.000000
# max    28.000000  100.000000  43.000000

# %%
#GET YEAR 2017 PERFORMANCE 
y2017 = df_plot[(df_plot.index > '2017-01-01')]
y2017.plot.line(title='2017 Performance')
# Out:
# <AxesSubplot:title={'center':'2017 Performance'}, xlabel='date'>

# %%
#GET YEAR 2016 PERFORMANCE 
y2016 = df_plot[(df_plot.index > '2016-01-01') & (df_plot.index < '2016-12-31')]
y2016.head()
y2016.plot.line(title='2016 Performance')
# Out:
# <AxesSubplot:title={'center':'2016 Performance'}, xlabel='date'>

# %%
def last_12m(df): 
    
    df = pd.DataFrame({
   'T1': df["top 1"].values,
   'T2': df["top 2"].values,
   'T3': df["top 3"].values
   }, index=pd.to_datetime(df["date"])
                    )
    return df.last('12M')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("trends1.csv", sep=",")
#Rearrange the columns date first 
df = df[['date','top 1','top 2','top 3']]
df["date"] = pd.to_datetime(df["date"])
df.head()
# Out:
#         date  top 1  top 2  top 3
# 0 2012-10-07      4     14     14
# 1 2012-10-14      7     15     18
# 2 2012-10-21      5     12     15
# 3 2012-10-28      5     15     12
# 4 2012-11-04      4     12     12

# %%
last_12m(df)
# Out:
#             T1   T2  T3
# date
# 2016-11-06  18   52  26
# 2016-11-13  21   55  25
# 2016-11-20  25   58  27
# 2016-11-27  28   61  25
# 2016-12-04  18   61  27
# 2016-12-11  19   55  22
# 2016-12-18  21   48  25
# 2016-12-25  27   57  24
# 2017-01-01  20   45  20
# 2017-01-08  23   49  24
# 2017-01-15  22   48  29
# 2017-01-22  24   48  25
# 2017-01-29  20   54  31
# 2017-02-05  18   55  24
# 2017-02-12  19   51  24
# 2017-02-19  21   59  28
# 2017-02-26  21   70  32
# 2017-03-05  21   66  31
# 2017-03-12  22   72  31
# 2017-03-19  22   72  31
# 2017-03-26  19   80  32
# 2017-04-02  23   81  35
# 2017-04-09  18   98  30
# 2017-04-16  22   90  38
# 2017-04-23  24   80  36
# 2017-04-30  19   82  36
# 2017-05-07  19   80  36
# 2017-05-14  19   88  40
# 2017-05-21  16   97  37
# 2017-05-28  21  100  41
# 2017-06-04  19   86  42
# 2017-06-11  20   96  43
# 2017-06-18  17   97  39
# 2017-06-25  18   95  37
# 2017-07-02  21   88  39
# 2017-07-09  21   92  40
# 2017-07-16  19   89  37
# 2017-07-23  19   96  37
# 2017-07-30  20   87  35
# 2017-08-06  19   77  36
# 2017-08-13  20   74  35
# 2017-08-20  19   73  34
# 2017-08-27  17   74  36
# 2017-09-03  18   72  35
# 2017-09-10  17   67  37
# 2017-09-17  18   66  32
# 2017-09-24  19   62  31
# 2017-10-01  20   78  27
